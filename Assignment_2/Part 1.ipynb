# %%
pip install nltk
# Out:
# Python interpreter will be restarted.
# ...
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# ...
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# ...
#   Using cached regex-2022.10.31-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (769 kB)
# ...
# Python interpreter will be restarted.

# %%
pip install -U spacy
# Out:
# Python interpreter will be restarted.
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Not uninstalling typing-extensions at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-be88bdf6-06d3-4352-9538-66244d0e3e1f
#     Can't uninstall 'typing-extensions'. No files were found to uninstall.
# ...
# Python interpreter will be restarted.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      |█████████                       |
#
# *** WARNING: max output size exceeded, skipping output. ***
#
#      |████████████████████████████████| 12.8 MB 5.2 MB/s
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-be88bdf6-06d3-4352-9538-66244d0e3e1f/bin/python -m pip install --upgrade pip' command.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import sys
import nltk
import spacy
import en_core_web_sm

rdd = sc.textFile("/FileStore/tables/tom_swift_and_his_flying_boat.txt")
sl = spacy.load("en_core_web_sm")
rddmap = rdd.map(lambda x:sl(x))
entities = rddmap.flatMap(lambda x:[w.text for w in x.ents])
pairs = entities.map(lambda x:(x,1))
count = pairs.reduceByKey(lambda x,y:x+y).sortBy(lambda x:-x[1])
count.take(175)
# Out:
# Out[7]: [('Tom', 464),
#  ('Ned', 137),
#  ('Damon', 116),
#  ('Koku', 106),
#  ('Mary', 90),
#  ('Tom Swift', 79),
#  ('Nestor', 69),
#  ('Winged Arrow', 67),
#  ('TOM SWIFT', 55),
#  ('Iceland', 55),
#  ('Karofsen', 54),
#  ('two', 52),
#  ('first', 51),
#  ('one', 49),
#  ('Project Gutenberg', 46),
#  ('Swift', 36),
#  ('Shopton', 27),
#  ('Rad', 26),
#  ('Ned Newton', 25),
#  ('Kingston', 24),
#  ('Wakefield Damon', 23),
#  ('Kalrye', 22),
#  ('Raddiker', 21),
#  ('Reykjavik', 19),
#  ('Brannigan', 18),
#  ('English', 17),
#  ('half', 15),
#  ('BUNNY BROWN', 14),
#  ('THE BOBBSEY TWINS', 13),
#  ('New York', 13),
#  ('Olaf Karofsen', 12),
#  ('TOM SLADE', 12),
#  ('the United States', 11),
#  ('GROSSET & DUNLAP', 11),
#  ('Mary Nestor', 11),
#  ('Gutenberg', 11),
#  ('Barton Swift', 10),
#  ('Danish', 10),
#  ('Greenland', 10),
#  ('five', 10),
#  ('NEW YORK', 9),
#  ('three', 9),
#  ('Denmark', 9),
#  ('eBook', 9),
#  ('Barton', 9),
#  ('Foundation', 9),
#  ('Arctic', 8),
# ...
